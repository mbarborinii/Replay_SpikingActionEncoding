# %% [markdown]
# # Run Spiking Action Memories Experiments

# %% [markdown]
# The goal of this script is to offer a basis for reproducible results in the Spiking Action Memories (SAMs) trained experiments. It could be used for hardware comparison (hopefully)

# %%
from Experiments import Utils

# %%
Utils.run_experiment_helper("INHEXC_1306")
# Out:
# 2026-07-06 15:06:56 - generic_experiment - INFO - Experiment created: Results/INHEXC_1306/generic_experiment
# Experiment created: Results/INHEXC_1306/generic_experiment
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Utils.run_experiment_helper("INHEXC_1306")
#
# File ~/code/Replay_SpikingActionEncoding/Experiments/Utils.py:67, in run_experiment_helper(experiment_name)
#      65 experiment_name = str("Results/" + experiment_name)
#      66 logger = ExperimentLogger(experiment_name)
# ---> 67 params = logger.load_model_full(model_name = experiment_name)
#      69 # assumes standard network structure
#      70 model = Module(name = experiment_name, params=params, layer1 = neuron_models.LIF, layer2 = neuron_models.SE_adRLIF, layer3=neuron_models.LI)
#
# File ~/code/Replay_SpikingActionEncoding/Utils_Functions/ExperimentLogger.py:126, in ExperimentLogger.load_model_full(self, model_name)
#     123 def load_model_full(self, model_name):
#     124     # Assumes above that the folder name is the same as the .pt file to load
#     125     path = os.path.join(self.models_dir, f"{model_name}.pt")
# --> 126     return torch.load(path)
#
# File ~/.virtualenvs/ActionEncoding/lib/python3.12/site-packages/torch/serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File ~/.virtualenvs/ActionEncoding/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/.virtualenvs/ActionEncoding/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Results/INHEXC_1306/generic_experiment/models/Results/INHEXC_1306.pt'
