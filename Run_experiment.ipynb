# %% [markdown]
# # Run Spiking Action Memories Experiments

# %% [markdown]
# The goal of this script is to offer a basis for reproducible results in the Spiking Action Memories (SAMs) trained experiments. It could be used for hardware comparison (hopefully)

# %%
from Experiments import Utils

# %%
Utils.run_experiment_helper("INHEXC_1306")
# Out:
# 2026-07-06 18:07:52 - generic_experiment - INFO - Experiment created: Results/INHEXC_1306/generic_experiment
# Experiment created: Results/INHEXC_1306/generic_experiment
# 2026-07-06 18:07:55 - generic_experiment - INFO - Teaching percentage: 0.50
# 2026-07-06 18:08:18 - generic_experiment - INFO - Epoch 1/1: Loss = 0.618441  Spikes = 15699815.0
# 2026-07-06 18:08:18 - generic_experiment - INFO - Results saved to Results/INHEXC_1306/generic_experiment/models/INHEXC_1306_test_results.npz
# Time 2026-07-06_18-08-18: Results saved to Results/INHEXC_1306/generic_experiment/models/INHEXC_1306_test_results.npz
# 2026-07-06 18:08:18 - generic_experiment - INFO - Rasters saved to Results/INHEXC_1306/generic_experiment/models/INHEXC_1306_test_results_rasters.npz
# Time 2026-07-06_18-08-18: Rasters saved to Results/INHEXC_1306/generic_experiment/models/INHEXC_1306_test_results_rasters.npz
